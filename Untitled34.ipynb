# %%
import pandas as pd

# %%
import numpy as np

# %%
t=pd.read_csv("E:\data\giri.csv")

# %%
df=t

# %%
df.head()
# Out:
#    Unnamed: 0                 date         segment                   country  \
# 0           0  2013-01-01 00:09:00  Small Business                    France
# 1           1  2013-01-01 00:09:00      Government                    Canada
# 2           2  2013-01-01 00:09:00      Government  United States of America
# 3           3  2013-01-01 00:09:00       Midmarket  United States of America
# 4           4  2013-01-01 00:09:00  Small Business                    Canada
#
#      product discountband  unitssold  manufacturingprice  saleprice  \
# 0   Montana       Medium       322.0                 5.0      300.0
# 1      Velo          Low      2646.0               120.0       20.0
# 2       VTT          Low       349.0               250.0      350.0
# 3     Paseo       Medium      2931.0                10.0       15.0
# 4   Montana       Medium      1283.0                 5.0      300.0
#
#    grosssales  discounts      sales      cogs  profit
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'date', 'segment', 'country', 'product', 'discountband',
#        'unitssold', 'manufacturingprice', 'saleprice', 'grosssales',
#        'discounts', 'sales', 'cogs', 'profit'],
#       dtype='object')

# %%
df.loc[:, ["unitssold"]]#alows us to access the row by rowname
# Out:
#      unitssold
# 0        322.0
# 1       2646.0
# 2        349.0
# 3       2931.0
# 4       1283.0
# ..         ...
# 642      570.0
# 643     1233.0
# 644      280.0
# 645     2852.0
# 646     2797.0
#
# [647 rows x 1 columns]

# %%
df.iloc[:4,:4].head()#it allows us to print row and columns
# Out:
#    Unnamed: 0                 date         segment                   country
# 0           0  2013-01-01 00:09:00  Small Business                    France
# 1           1  2013-01-01 00:09:00      Government                    Canada
# 2           2  2013-01-01 00:09:00      Government  United States of America
# 3           3  2013-01-01 00:09:00       Midmarket  United States of America

# %%
df[df["segment"]>4000]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-154382aabc29> in <module>
# ----> 1 df[df["segment"]>4000]
#
# E:\anakonda\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      62         other = item_from_zerodim(other)
#      63
# ---> 64         return method(self, other)
#      65
#      66     return new_method
#
# E:\anakonda\lib\site-packages\pandas\core\ops\__init__.py in wrapper(self, other)
#     527         rvalues = extract_array(other, extract_numpy=True)
#     528
# --> 529         res_values = comparison_op(lvalues, rvalues, op)
#     530
#     531         return _construct_result(self, res_values, index=self.index, name=res_name)
#
# E:\anakonda\lib\site-packages\pandas\core\ops\array_ops.py in comparison_op(left, right, op)
#     245
#     246     elif is_object_dtype(lvalues.dtype):
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'date', 'segment', 'country', 'product', 'discountband',
#        'unitssold', 'manufacturingprice', 'saleprice', 'grosssales',
#        'discounts', 'sales', 'cogs', 'profit'],
#       dtype='object')

# %%
df[(df["sales"]>4000) & (df["profit"]==10)]
#df.profit
# Out:
#      Unnamed: 0                 date           segment  \
# 3             3  2013-01-01 00:09:00         Midmarket
# 6             6  2013-01-01 00:09:00         Midmarket
# 7             7  2013-01-01 00:09:00        Government
# 14           14  2013-01-01 00:09:00    Small Business
# 17           17  2013-01-01 00:09:00        Government
# ..          ...                  ...               ...
# 638         638  2014-01-01 00:12:00        Enterprise
# 639         639  2014-01-01 00:12:00  Channel Partners
# 640         640  2014-01-01 00:12:00  Channel Partners
# 643         643  2014-01-01 00:12:00        Government
# 645         645  2014-01-01 00:12:00        Government
#
#                       country  product discountband  unitssold  \
# 3    United States of America   Paseo       Medium      2931.0
# 6                      Canada   Paseo         High      2470.0
# 7                      Canada   Paseo       Medium      2349.0
# ...

# %%
df.iloc[:10,5][5]
# Out:
# ' High '

# %%
#my mad i am quite

# %%
high=df[df["discountband"]==' High ']

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'date', 'segment', 'country', 'product', 'discountband',
#        'unitssold', 'manufacturingprice', 'saleprice', 'grosssales',
#        'discounts', 'sales', 'cogs', 'profit'],
#       dtype='object')

# %%
df.loc[high]
#df.loc[:,"sales":"profit"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-a77c25525bac> in <module>
# ----> 1 df.loc[high]
#       2 #df.loc[:,"sales":"profit"]
#
# E:\anakonda\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1766
#    1767             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1768             return self._getitem_axis(maybe_callable, axis=axis)
#    1769
#    1770     def _is_scalar_access(self, key: Tuple):
#
# E:\anakonda\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1950
#    1951                 if hasattr(key, "ndim") and key.ndim > 1:
# -> 1952                     raise ValueError("Cannot index with multidimensional key")
#    1953
#    1954                 return self._getitem_iterable(key, axis=axis)
#
# ValueError: Cannot index with multidimensional key

# %%
df.columns[-3:]
# Out:
# Index(['sales', 'cogs', 'profit'], dtype='object')
