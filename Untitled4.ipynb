# %%
import pandas as pd
df=pd.read_csv("c:\\Users\\user\\Downloads\\siva.csv")

# %%
df.columns=df.columns.str.replace(" ","")

# %%
df.head()
# Out:
#       Segment  Country      Product DiscountBand  UnitsSold  \
# 0  Government   Canada   Carretera         None      1618.5
# 1  Government  Germany   Carretera         None      1321.0
# 2   Midmarket   France   Carretera         None      2178.0
# 3   Midmarket  Germany   Carretera         None       888.0
# 4   Midmarket   Mexico   Carretera         None      2470.0
#
#   ManufacturingPrice SalePrice    GrossSales Discounts         Sales  \
# 0             $3.00    $20.00    $32,370.00      $-      $32,370.00
# 1             $3.00    $20.00    $26,420.00      $-      $26,420.00
# 2             $3.00    $15.00    $32,670.00      $-      $32,670.00
# 3             $3.00    $15.00    $13,320.00      $-      $13,320.00
# 4             $3.00    $15.00    $37,050.00      $-      $37,050.00
#
#            COGS        Profit        Date  MonthNumber  MonthName  Year
# 0   $16,185.00    $16,185.00   01/01/2014            1   January   2014
# ...

# %%
df.shape
# Out:
# (700, 16)

# %%
df.isnull().sum()
# Out:
# Segment               0
# Country               0
# Product               0
# DiscountBand          0
# UnitsSold             0
# ManufacturingPrice    0
# SalePrice             0
# GrossSales            0
# Discounts             0
# Sales                 0
# COGS                  0
# Profit                0
# Date                  0
# MonthNumber           0
# MonthName             0
# Year                  0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Segment', 'Country', 'Product', 'DiscountBand', 'UnitsSold',
#        'ManufacturingPrice', 'SalePrice', 'GrossSales', 'Discounts', 'Sales',
#        'COGS', 'Profit', 'Date', 'MonthNumber', 'MonthName', 'Year'],
#       dtype='object')

# %%
df.head()
# Out:
#       Segment  Country      Product DiscountBand  UnitsSold  \
# 0  Government   Canada   Carretera         None      1618.5
# 1  Government  Germany   Carretera         None      1321.0
# 2   Midmarket   France   Carretera         None      2178.0
# 3   Midmarket  Germany   Carretera         None       888.0
# 4   Midmarket   Mexico   Carretera         None      2470.0
#
#   ManufacturingPrice SalePrice    GrossSales Discounts         Sales  \
# 0             $3.00    $20.00    $32,370.00      $-      $32,370.00
# 1             $3.00    $20.00    $26,420.00      $-      $26,420.00
# 2             $3.00    $15.00    $32,670.00      $-      $32,670.00
# 3             $3.00    $15.00    $13,320.00      $-      $13,320.00
# 4             $3.00    $15.00    $37,050.00      $-      $37,050.00
#
#            COGS        Profit        Date  MonthNumber  MonthName  Year
# 0   $16,185.00    $16,185.00   01/01/2014            1   January   2014
# ...

# %%
df.columns=[s.lower() for s  in df.columns]

# %%
df[df["segment"]=="Government"].shape
# Out:
# (300, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   segment             700 non-null    object
#  1   country             700 non-null    object
#  2   product             700 non-null    object
#  3   discountband        700 non-null    object
#  4   unitssold           700 non-null    float64
#  5   manufacturingprice  700 non-null    object
#  6   saleprice           700 non-null    object
#  7   grosssales          700 non-null    object
#  8   discounts           700 non-null    object
#  9   sales               700 non-null    object
#  10  cogs                700 non-null    object
#  11  profit              700 non-null    object
#  12  date                700 non-null    object
#  13  monthnumber         700 non-null    int64
#  14  monthname           700 non-null    object
# ...

# %%
df[(df["segment"]=="Government")&(df["unitssold"]>1500)]
# Out:
#         segment                   country      product discountband  \
# 0    Government                    Canada   Carretera         None
# 5    Government                   Germany   Carretera         None
# 8    Government                    France     Montana         None
# 13   Government                   Germany     Montana         None
# 26   Government                    Canada       Paseo         None
# ..          ...                       ...          ...          ...
# 664  Government                    Mexico    Amarilla         High
# 672  Government                    Mexico       Paseo         High
# 673  Government                    Mexico       Paseo         High
# 678  Government  United States of America       Paseo         High
# 679  Government                    Mexico       Paseo         High
#
#      unitssold manufacturingprice  saleprice      grosssales       discounts  \
# 0       1618.5             $3.00     $20.00      $32,370.00            $-
# ...

# %%
country=["Canda","Germany","France","India"]
f=df["country"].isin(country)
df.loc[f]
# Out:
#             segment  country      product discountband  unitssold  \
# 1        Government  Germany   Carretera         None      1321.0
# 2         Midmarket   France   Carretera         None      2178.0
# 3         Midmarket  Germany   Carretera         None       888.0
# 5        Government  Germany   Carretera         None      1513.0
# 6         Midmarket  Germany     Montana         None       921.0
# ..              ...      ...          ...          ...        ...
# 689       Midmarket  Germany         VTT         High       492.0
# 691       Midmarket  Germany         VTT         High      1175.0
# 693      Enterprise  Germany         VTT         High       552.0
# 694      Government   France         VTT         High       293.0
# 695  Small Business   France    Amarilla         High      2475.0
#
#     manufacturingprice  saleprice      grosssales       discounts  \
# 1               $3.00     $20.00      $26,420.00            $-
# ...

# %%
df.columns
# Out:
# Index(['segment', 'country', 'product', 'discountband', 'unitssold',
#        'manufacturingprice', 'saleprice', 'grosssales', 'discounts', 'sales',
#        'cogs', 'profit', 'date', 'monthnumber', 'monthname', 'year'],
#       dtype='object')

# %%
df.columns=["Segment","Country","Product","Discountband","Unitssold","Manufacturingprice","Saleprice",'Grosssales',"Discounts",\
            "sales","Cogs","Profit","Date","Monthnumber","MonthName","Year"]

# %%
df.columns
# Out:
# Index(['Segment', 'Country', 'Product', 'Discountband', 'Unitssold',
#        'Manufacturingprice', 'Saleprice', 'Grosssales', 'Discounts', 'sales',
#        'Cogs', 'Profit', 'Date', 'Monthnumber', 'MonthName', 'Year'],
#       dtype='object')

# %%
df.columns=[s.lower() for s in df.columns]

# %%
df.head()
# Out:
#       segment  country      product discountband  unitssold  \
# 0  Government   Canada   Carretera         None      1618.5
# 1  Government  Germany   Carretera         None      1321.0
# 2   Midmarket   France   Carretera         None      2178.0
# 3   Midmarket  Germany   Carretera         None       888.0
# 4   Midmarket   Mexico   Carretera         None      2470.0
#
#   manufacturingprice saleprice    grosssales discounts         sales  \
# 0             $3.00    $20.00    $32,370.00      $-      $32,370.00
# 1             $3.00    $20.00    $26,420.00      $-      $26,420.00
# 2             $3.00    $15.00    $32,670.00      $-      $32,670.00
# 3             $3.00    $15.00    $13,320.00      $-      $13,320.00
# 4             $3.00    $15.00    $37,050.00      $-      $37,050.00
#
#            cogs        profit        date  monthnumber  monthname  year
# 0   $16,185.00    $16,185.00   01/01/2014            1   January   2014
# ...

# %%
#df.discountband.value_counts()
import numpy as np
#df["discountban"]=df.discountband.replace({"None":np.nan,"High":"high","Medium":"medium","Low":"low"})
#df.discountband.value_counts()
#df.discountband.dtype
df.tail()
# Out:
#               segment                   country     product discountband  \
# 695    Small Business                    France   Amarilla         High
# 696    Small Business                    Mexico   Amarilla         High
# 697        Government                    Mexico    Montana         High
# 698        Government                    Canada      Paseo         High
# 699  Channel Partners  United States of America        VTT         High
#
#      unitssold manufacturingprice  saleprice      grosssales       discounts  \
# 695     2475.0           $260.00    $300.00    $7,42,500.00    $1,11,375.00
# 696      546.0           $260.00    $300.00    $1,63,800.00      $24,570.00
# 697     1368.0             $5.00      $7.00       $9,576.00       $1,436.40
# 698      723.0            $10.00      $7.00       $5,061.00         $759.15
# 699     1806.0           $250.00     $12.00      $21,672.00       $3,250.80
#
# ...

# %%
df.tail()
# Out:
#               segment                   country     product discountband  \
# 695    Small Business                    France   Amarilla         High
# 696    Small Business                    Mexico   Amarilla         High
# 697        Government                    Mexico    Montana         High
# 698        Government                    Canada      Paseo         High
# 699  Channel Partners  United States of America        VTT         High
#
#      unitssold manufacturingprice  saleprice      grosssales       discounts  \
# 695     2475.0           $260.00    $300.00    $7,42,500.00    $1,11,375.00
# 696      546.0           $260.00    $300.00    $1,63,800.00      $24,570.00
# 697     1368.0             $5.00      $7.00       $9,576.00       $1,436.40
# 698      723.0            $10.00      $7.00       $5,061.00         $759.15
# 699     1806.0           $250.00     $12.00      $21,672.00       $3,250.80
#
# ...

# %%
df.discountband.value_counts()
# Out:
#  High       245
#  Medium     242
#  Low        160
#  None        53
# Name: discountband, dtype: int64

# %%
df["discountband"].replace({"None":np.nan,"High":"loaa"})
# Out:
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
#         ...
# 695     High
# 696     High
# 697     High
# 698     High
# 699     High
# Name: discountband, Length: 700, dtype: object

# %%
df.discountband.isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 695    False
# 696    False
# 697    False
# 698    False
# 699    False
# Name: discountband, Length: 700, dtype: bool

# %%
df["saleprice"]=df["saleprice"].astype(int).apply(lambda s:s.replace(" $",""))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-170-43fd770be182> in <module>
# ----> 1 df["saleprice"]=df["saleprice"].astype(int).apply(lambda s:s.replace(" $",""))
#
# E:\anakonda\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# E:\anakonda\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
#     584     def convert(self, **kwargs):
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   segment             700 non-null    object
#  1   country             700 non-null    object
#  2   product             700 non-null    object
#  3   discountband        700 non-null    object
#  4   unitssold           700 non-null    float64
#  5   manufacturingprice  700 non-null    object
#  6   saleprice           700 non-null    object
#  7   grosssales          700 non-null    object
#  8   discounts           700 non-null    object
#  9   sales               700 non-null    object
#  10  cogs                700 non-null    object
#  11  profit              700 non-null    object
#  12  date                700 non-null    object
#  13  monthnumber         700 non-null    int64
#  14  monthname           700 non-null    object
# ...
