# %%
import pandas as pd
import numpy as np
#import matplotlib.plot as plot
import seaborn as sns

# %%
df=pd.read_csv("E:\\data\\giri.csv")

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'date', 'segment', 'country', 'product', 'discountband',
#        'unitssold', 'manufacturingprice', 'saleprice', 'grosssales',
#        'discounts', 'sales', 'cogs', 'profit'],
#       dtype='object')

# %%
df.drop('Unnamed: 0',inplace=True,axis=1)

# %%
df.columns
# Out:
# Index(['date', 'segment', 'country', 'product', 'discountband', 'unitssold',
#        'manufacturingprice', 'saleprice', 'grosssales', 'discounts', 'sales',
#        'cogs', 'profit'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 647 entries, 0 to 646
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   date                647 non-null    object
#  1   segment             647 non-null    object
#  2   country             647 non-null    object
#  3   product             647 non-null    object
#  4   discountband        647 non-null    object
#  5   unitssold           647 non-null    float64
#  6   manufacturingprice  647 non-null    float64
#  7   saleprice           647 non-null    float64
#  8   grosssales          647 non-null    float64
#  9   discounts           647 non-null    float64
#  10  sales               647 non-null    float64
#  11  cogs                647 non-null    float64
#  12  profit              647 non-null    float64
# dtypes: float64(8), object(5)
# memory usage: 65.8+ KB

# %%
sns.distplot(df.saleprice)

# %%
sns.distplot(df.manufacturingprice)

# %%
sns.distplot(df.profit)

# %%
sns.distplot(df.unitssold )

# %%
sns.distplot(df.grosssales)

# %%
sns.distplot(df.discounts)

# %%
sns.distplot(df.cogs  )
