# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv("E:\data\hari.csv")
# Out:
# E:\anakonda\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (10,65,85) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.head()
# Out:
#       site Warehouse   Type  Order Month Order Created By  Order Created Date  \
# 0  BLRB012  BLRB012A  Sales            7          W017053               44018
# 1  BLRB012  BLRB012A  Sales            7          W008075               44020
# 2  BLRB013  BLRB013D  Sales            7          W008075               44019
# 3  BLRB012  BLRB012A  Sales            7          W008075               44019
# 4  BLRB012  BLRB012A  Sales            7          W008075               44019
#
#    Order Created Time     Order No.  Customer / WH       Customer / WH Name  \
# 0            0.589514  SO_001457910          10180  Buhler (India) Pvt. Ltd
# 1            0.695162  SO_001464869          10490             Parkash Sons
# 2            0.699306  SO_001461049          10555            RANVIR STUDIO
# 3            0.706250  SO_001461050          10555            RANVIR STUDIO
# 4            0.708067  SO_001461051          10555            RANVIR STUDIO
#
# ...

# %%
df.columns
# Out:
# Index(['site', 'Warehouse', 'Type', 'Order Month', 'Order Created By',
#        'Order Created Date', 'Order Created Time', 'Order No.',
#        'Customer / WH', 'Customer / WH Name', 'Zone', 'Branch', 'Ship to City',
#        'Ship to State', 'Ship to Pin Code', 'Customer Block Status',
#        'Actual / Virtual', 'Channel', 'Customer Group',
#        'External Doc / Customer PO No.', 'Consignment Id', 'Order Status',
#        'Order Qty', 'Order Value', 'IOrder No.', 'Picklist No.',
#        'Picklist Generated Date', 'Picklist Generated Time', 'PL Type',
#        'PL status', 'PL Handelling Status', 'Status', 'Picklist Generated Qty',
#        'Picklist Released Date', 'Picklist Released Time',
#        'Pending to be Released Qty', 'Pending to be Generated Qty',
#        'Order PL Released Qty', 'IOrder Qty', 'PL Released - IOrder Qty',
#        'Shipped Qty (3PL)', 'Load Save Qty', 'PL registered Qty',
# ...

# %%
df.columns=[i.lower() for i in df.columns]

# %%
df.columns
# Out:
# Index(['site', 'warehouse', 'type', 'order month', 'order created by',
#        'order created date', 'order created time', 'order no.',
#        'customer / wh', 'customer / wh name', 'zone', 'branch', 'ship to city',
#        'ship to state', 'ship to pin code', 'customer block status',
#        'actual / virtual', 'channel', 'customer group',
#        'external doc / customer po no.', 'consignment id', 'order status',
#        'order qty', 'order value', 'iorder no.', 'picklist no.',
#        'picklist generated date', 'picklist generated time', 'pl type',
#        'pl status', 'pl handelling status', 'status', 'picklist generated qty',
#        'picklist released date', 'picklist released time',
#        'pending to be released qty', 'pending to be generated qty',
#        'order pl released qty', 'iorder qty', 'pl released - iorder qty',
#        'shipped qty (3pl)', 'load save qty', 'pl registered qty',
# ...

# %%
df.columns=df.columns.str.replace("\s|\-|\.","")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20048 entries, 0 to 20047
# Data columns (total 86 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   site                            20047 non-null  object
#  1   warehouse                       20048 non-null  object
#  2   type                            20048 non-null  object
#  3   ordermonth                      20048 non-null  int64
#  4   ordercreatedby                  20048 non-null  object
#  5   ordercreateddate                20048 non-null  int64
#  6   ordercreatedtime                20048 non-null  float64
#  7   orderno                         20048 non-null  object
#  8   customer/wh                     20048 non-null  int64
#  9   customer/whname                 20048 non-null  object
#  10  zone                            73 non-null     object
#  11  branch                          20047 non-null  object
# ...

# %%
#df.dropna(axis=1,inplace=True,how="all",thresh=20000)
df.drop(["remarks","appointmentdate","appointmentsharedtologisticson","iorderno","ptrno","ptrdate","actualpoddate","piamodifieddate","waybillreceivedon","appointmentdate","appointmentsharedtologisticson"],axis="columns",inplace=True)

# %%
df.shape
# Out:
# (20048, 77)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20048 entries, 0 to 20047
# Data columns (total 77 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   site                      20047 non-null  object
#  1   warehouse                 20048 non-null  object
#  2   type                      20048 non-null  object
#  3   ordermonth                20048 non-null  int64
#  4   ordercreatedby            20048 non-null  object
#  5   ordercreateddate          20048 non-null  int64
#  6   ordercreatedtime          20048 non-null  float64
#  7   orderno                   20048 non-null  object
#  8   customer/wh               20048 non-null  int64
#  9   customer/whname           20048 non-null  object
#  10  zone                      73 non-null     object
#  11  branch                    20047 non-null  object
#  12  shiptocity                20046 non-null  object
# ...

# %%
df.drop(["pbdpaymentconfirmdate"],axis=1,inplace=True)

# %%
df.shape
# Out:
# (20048, 76)

# %%
df.
