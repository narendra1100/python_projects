# %%
import pandas as pd
import seaborn as sns
import numpy as np
from matplotlib import pyplot as plt

# %%
df=pd.read_csv("E:\\data\\update_task.csv")

# %%
df.head()
# Out:
#    host_id                                  host_url  host_name  host_since  \
# 0   266763  https://www.airbnb.com/users/show/266763  Francesca  20-10-2010
# 1   227796  https://www.airbnb.com/users/show/227796    Sujatha  08-09-2010
# 2   266763  https://www.airbnb.com/users/show/266763  Francesca  20-10-2010
# 3   367042  https://www.airbnb.com/users/show/367042    Belinda  29-01-2011
# 4   367042  https://www.airbnb.com/users/show/367042    Belinda  29-01-2011
#
#           host_location  host_response_time  host_response_rate  \
# 0             singapore  within a few hours                 1.0
# 1  Singapore, Singapore                 NaN                 NaN
# 2             singapore  within a few hours                 1.0
# 3             Singapore  within a few hours                 1.0
# 4             Singapore  within a few hours                 1.0
#
#   host_is_superhost                                 host_thumbnail_url  \
# ...

# %%
df.drop(["host_id","host_url","host_thumbnail_url","host_picture_url"],axis="columns",inplace=True)

# %%
df.head()
# Out:
#    host_name  host_since         host_location  host_response_time  \
# 0  Francesca  20-10-2010             singapore  within a few hours
# 1    Sujatha  08-09-2010  Singapore, Singapore                 NaN
# 2  Francesca  20-10-2010             singapore  within a few hours
# 3    Belinda  29-01-2011             Singapore  within a few hours
# 4    Belinda  29-01-2011             Singapore  within a few hours
#
#    host_response_rate host_is_superhost  \
# 0                 1.0                 f
# 1                 NaN                 f
# 2                 1.0                 f
# 3                 1.0                 f
# 4                 1.0                 f
#
#                                   host_verifications host_identity_verified  \
# 0  ['email', 'phone', 'facebook', 'reviews', 'jum...                      f
# 1  ['email', 'phone', 'facebook', 'reviews', 'off...                      f
# 2  ['email', 'phone', 'facebook', 'reviews', 'jum...                      f
# ...

# %%
df.columns
# Out:
# Index(['host_name', 'host_since', 'host_location', 'host_response_time',
#        'host_response_rate', 'host_is_superhost', 'host_verifications',
#        'host_identity_verified', 'neighbourhood', 'neighbourhood_group',
#        'state', 'zipcode', 'latitude', 'longitude', 'is_location_exact',
#        'property_type', 'room_type', 'accommodates', 'bathrooms', 'bedrooms',
#        'beds', 'amenities', 'price', 'security_deposit', 'cleaning_fee',
#        'guests_included', 'extra_people', 'minimum_nights', 'maximum_nights',
#        'number_of_reviews', 'number_of_reviews_ltm', 'review_scores_rating',
#        'instant_bookable', 'cancellation_policy',
#        'calculated_host_listings_count', 'reviews_per_month'],
#       dtype='object')

# %%
df.drop(["host_name"],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['host_since', 'host_location', 'host_response_time',
#        'host_response_rate', 'host_is_superhost', 'host_verifications',
#        'host_identity_verified', 'neighbourhood', 'neighbourhood_group',
#        'state', 'zipcode', 'latitude', 'longitude', 'is_location_exact',
#        'property_type', 'room_type', 'accommodates', 'bathrooms', 'bedrooms',
#        'beds', 'amenities', 'price', 'security_deposit', 'cleaning_fee',
#        'guests_included', 'extra_people', 'minimum_nights', 'maximum_nights',
#        'number_of_reviews', 'number_of_reviews_ltm', 'review_scores_rating',
#        'instant_bookable', 'cancellation_policy',
#        'calculated_host_listings_count', 'reviews_per_month'],
#       dtype='object')

# %%
df.host_since.isnull().sum()
# Out:
# 4

# %%
df[df.host_is_superhost.isnull()]
# Out:
#      host_since host_location host_response_time  host_response_rate  \
# 5971        NaN           NaN                NaN                 NaN
#
#      host_is_superhost host_verifications host_identity_verified  \
# 5971               NaN               None                    NaN
#
#      neighbourhood neighbourhood_group state  ... extra_people  \
# 5971   Jurong West         West Region   NaN  ...           20
#
#       minimum_nights  maximum_nights number_of_reviews number_of_reviews_ltm  \
# 5971              90            1125                 0                     0
#
#      review_scores_rating  instant_bookable          cancellation_policy  \
# 5971                  NaN                 f  strict_14_with_grace_period
#
#       calculated_host_listings_count  reviews_per_month
# 5971                               1                NaN
#
# [1 rows x 35 columns]

# %%
df.drop(5971,inplace=True)

# %%
df.head()
# Out:
#    host_since         host_location  host_response_time  host_response_rate  \
# 0  20-10-2010             singapore  within a few hours                 1.0
# 1  08-09-2010  Singapore, Singapore                 NaN                 NaN
# 2  20-10-2010             singapore  within a few hours                 1.0
# 3  29-01-2011             Singapore  within a few hours                 1.0
# 4  29-01-2011             Singapore  within a few hours                 1.0
#
#   host_is_superhost                                 host_verifications  \
# 0                 f  ['email', 'phone', 'facebook', 'reviews', 'jum...
# 1                 f  ['email', 'phone', 'facebook', 'reviews', 'off...
# 2                 f  ['email', 'phone', 'facebook', 'reviews', 'jum...
# 3                 f  ['email', 'phone', 'reviews', 'manual_offline'...
# 4                 f  ['email', 'phone', 'reviews', 'manual_offline'...
#
#   host_identity_verified neighbourhood neighbourhood_group state  ...  \
# ...

# %%
df.host_verifications.isnull().sum()
# Out:
# 0

# %%
df.to_csv("E:\\data\\update_task.csv",index=False)

# %%
df=pd.read_csv("E:\\data\\update_task.csv")

# %%
df.head()
# Out:
#    host_since         host_location  host_response_time  host_response_rate  \
# 0  20-10-2010             singapore  within a few hours                 1.0
# 1  08-09-2010  Singapore, Singapore                 NaN                 NaN
# 2  20-10-2010             singapore  within a few hours                 1.0
# 3  29-01-2011             Singapore  within a few hours                 1.0
# 4  29-01-2011             Singapore  within a few hours                 1.0
#
#   host_is_superhost                                 host_verifications  \
# 0                 f  ['email', 'phone', 'facebook', 'reviews', 'jum...
# 1                 f  ['email', 'phone', 'facebook', 'reviews', 'off...
# 2                 f  ['email', 'phone', 'facebook', 'reviews', 'jum...
# 3                 f  ['email', 'phone', 'reviews', 'manual_offline'...
# 4                 f  ['email', 'phone', 'reviews', 'manual_offline'...
#
#   host_identity_verified neighbourhood neighbourhood_group state  ...  \
# ...

# %%
df.columns
# Out:
# Index(['host_since', 'host_location', 'host_response_time',
#        'host_response_rate', 'host_is_superhost', 'host_verifications',
#        'host_identity_verified', 'neighbourhood', 'neighbourhood_group',
#        'state', 'zipcode', 'latitude', 'longitude', 'is_location_exact',
#        'property_type', 'room_type', 'accommodates', 'bathrooms', 'bedrooms',
#        'beds', 'amenities', 'price', 'security_deposit', 'cleaning_fee',
#        'guests_included', 'extra_people', 'minimum_nights', 'maximum_nights',
#        'number_of_reviews', 'number_of_reviews_ltm', 'review_scores_rating',
#        'instant_bookable', 'cancellation_policy',
#        'calculated_host_listings_count', 'reviews_per_month'],
#       dtype='object')

# %%
df.host_since.isnull().sum()
# Out:
# 3

# %%
df.head()
# Out:
#    host_since         host_location  host_response_time  host_response_rate  \
# 0  20-10-2010             singapore  within a few hours                 1.0
# 1  08-09-2010  Singapore, Singapore                 NaN                 NaN
# 2  20-10-2010             singapore  within a few hours                 1.0
# 3  29-01-2011             Singapore  within a few hours                 1.0
# 4  29-01-2011             Singapore  within a few hours                 1.0
#
#   host_is_superhost                                 host_verifications  \
# 0                 f  ['email', 'phone', 'facebook', 'reviews', 'jum...
# 1                 f  ['email', 'phone', 'facebook', 'reviews', 'off...
# 2                 f  ['email', 'phone', 'facebook', 'reviews', 'jum...
# 3                 f  ['email', 'phone', 'reviews', 'manual_offline'...
# 4                 f  ['email', 'phone', 'reviews', 'manual_offline'...
#
#   host_identity_verified neighbourhood neighbourhood_group state  ...  \
# ...

# %%
d=pd.read_csv("E:\\data\\task.csv")

# %%
df.drop("state",axis=1,inplace=True)

# %%
df.head()
# Out:
#    host_since         host_location  host_response_time  host_response_rate  \
# 0  20-10-2010             singapore  within a few hours                 1.0
# 1  08-09-2010  Singapore, Singapore                 NaN                 NaN
# 2  20-10-2010             singapore  within a few hours                 1.0
# 3  29-01-2011             Singapore  within a few hours                 1.0
# 4  29-01-2011             Singapore  within a few hours                 1.0
#
#   host_is_superhost                                 host_verifications  \
# 0                 f  ['email', 'phone', 'facebook', 'reviews', 'jum...
# 1                 f  ['email', 'phone', 'facebook', 'reviews', 'off...
# 2                 f  ['email', 'phone', 'facebook', 'reviews', 'jum...
# 3                 f  ['email', 'phone', 'reviews', 'manual_offline'...
# 4                 f  ['email', 'phone', 'reviews', 'manual_offline'...
#
#   host_identity_verified neighbourhood neighbourhood_group zipcode  ...  \
# ...

# %%
df.columns
# Out:
# Index(['host_since', 'host_location', 'host_response_time',
#        'host_response_rate', 'host_is_superhost', 'host_verifications',
#        'host_identity_verified', 'neighbourhood', 'neighbourhood_group',
#        'zipcode', 'latitude', 'longitude', 'is_location_exact',
#        'property_type', 'room_type', 'accommodates', 'bathrooms', 'bedrooms',
#        'beds', 'amenities', 'price', 'security_deposit', 'cleaning_fee',
#        'guests_included', 'extra_people', 'minimum_nights', 'maximum_nights',
#        'number_of_reviews', 'number_of_reviews_ltm', 'review_scores_rating',
#        'instant_bookable', 'cancellation_policy',
#        'calculated_host_listings_count', 'reviews_per_month'],
#       dtype='object')

# %%
#df.drop(df[df.host_since.isnull()].index,inplace=True)
plt.scatter(df.host_verifications,df.price)

# %%
#df.host_since.isnull().sum()

# %%
df[df["host_since"]=='https://a0.muscache.com/im/pictures/bdb1b01f-9366-49c4-a04c-d08985e11dfc.jpg?aki_policy=large']
# Out:
#                                              host_since host_location  \
# 2953  https://a0.muscache.com/im/pictures/bdb1b01f-9...            IN
#
#      host_response_time  host_response_rate host_is_superhost  \
# 2953     within an hour                0.96                 f
#
#                                      host_verifications  \
# 2953  ['email', 'phone', 'reviews', 'jumio', 'offlin...
#
#      host_identity_verified  neighbourhood neighbourhood_group zipcode  ...  \
# 2953                      f  Marine Parade      Central Region     NaN  ...
#
#       extra_people  minimum_nights maximum_nights number_of_reviews  \
# 2953             0               7           1125                 0
#
#      number_of_reviews_ltm  review_scores_rating  instant_bookable  \
# 2953                     0                   NaN                 f
#
#               cancellation_policy  calculated_host_listings_count  \
# 2953  strict_14_with_grace_period                              72
#
# ...

# %%
df.drop(2953,inplace=True)

# %%
df.shape
# Out:
# (7670, 34)

# %%
df.drop(["host_verifications"],axis="columns",inplace=True)

# %%
df.drop(df[df["host_since"]=="https://a0.muscache.com/im/pictures/0571b58e-0abb-4191-84d5-2cf89e5ad8a2.jpg?aki_policy=large"].index,inplace=True)

# %%
df["host_since"]=pd.to_datetime(df["host_since"],format="%d-%m-%Y")

# %%
t=[]
no=[]
def dates(df):
    try:
        t.append(pd.to_datetime(df["host_since"].index,format="%d-%m-%Y"))
        print(t)
    except:
        print("sorry")

# %%
#pd.to_datetime(df["host_since"].index,format="%d-%m-%Y"

# %%
df.host_since.max()-df.host_since.min()
# Out:
# Timedelta('3739 days 00:00:00')

# %%
df.sort_values(by="host_since",inplace=True)

# %%
df.isnull().sum()
# Out:
# host_since                           0
# host_location                       18
# host_response_time                1402
# host_response_rate                1402
# host_is_superhost                    0
# host_identity_verified               0
# neighbourhood                        4
# neighbourhood_group                  0
# zipcode                            827
# latitude                             0
# longitude                            0
# is_location_exact                    0
# property_type                        0
# room_type                            0
# accommodates                         0
# bathrooms                            5
# bedrooms                             2
# beds                                14
# amenities                            0
# price                                0
# security_deposit                  2292
# cleaning_fee                      2055
# guests_included                      0
# extra_people                         0
# ...

# %%
df.to_csv("E:\\data\\update_task.csv")

# %%
df.shape
# Out:
# (7665, 33)
