# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("E:\\data\\hari.csv")
# Out:
# E:\anakonda\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (10,61) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.head()
# Out:
#       site warehouse   type  ordermonth ordercreatedby  ordercreateddate  \
# 0  BLRB012  BLRB012A  Sales           7        W017053             44018
# 1  BLRB012  BLRB012A  Sales           7        W008075             44020
# 2  BLRB013  BLRB013D  Sales           7        W008075             44019
# 3  BLRB012  BLRB012A  Sales           7        W008075             44019
# 4  BLRB012  BLRB012A  Sales           7        W008075             44019
#
#    ordercreatedtime       orderno  customer/wh          customer/whname  ...  \
# 0          0.589514  SO_001457910        10180  Buhler (India) Pvt. Ltd  ...
# 1          0.695162  SO_001464869        10490             Parkash Sons  ...
# 2          0.699306  SO_001461049        10555            RANVIR STUDIO  ...
# 3          0.706250  SO_001461050        10555            RANVIR STUDIO  ...
# 4          0.708067  SO_001461051        10555            RANVIR STUDIO  ...
#
# ...

# %%
df.columns
# Out:
# Index(['site', 'warehouse', 'type', 'ordermonth', 'ordercreatedby',
#        'ordercreateddate', 'ordercreatedtime', 'orderno', 'customer/wh',
#        'customer/whname', 'zone', 'branch', 'shiptocity', 'shiptostate',
#        'shiptopincode', 'customerblockstatus', 'actual/virtual', 'channel',
#        'customergroup', 'externaldoc/customerpono', 'consignmentid',
#        'orderstatus', 'orderqty', 'ordervalue', 'picklistno',
#        'picklistgenerateddate', 'picklistgeneratedtime', 'pltype', 'plstatus',
#        'plhandellingstatus', 'status', 'picklistgeneratedqty',
#        'picklistreleaseddate', 'picklistreleasedtime',
#        'pendingtobereleasedqty', 'pendingtobegeneratedqty',
#        'orderplreleasedqty', 'iorderqty', 'plreleasediorderqty',
#        'shippedqty(3pl)', 'loadsaveqty', 'plregisteredqty', 'invoice/ptsqty',
#        'iorderinvoiceqty', 'loadsaveinvoiceqty', 'registeredqtyinvoiceqty',
#        'ptrqty', 'whfillrate', 'bisnessfillrate', 'invoice/ptsno',
# ...

# %%
import seaborn as sns
df.columns=df.columns.str.replace("\/|\(|\)","_")
#df.branch.value_counts(normalize=True)
#sns.distplot(df.estdeliverydate.value_counts(),bins=5)

d=["site","type","ordermonth","ordercreatedby","branch","customerblockstatus","actual_virtual","channel","customergroup","orderstatus","pltype","plstatus","plhandellingstatus","status","pendingtobereleasedqty","iorderqty","shippedqty_3pl_","loadsaveqty","registeredqtyinvoiceqty","ptrqty","whfillrate","bisnessfillrate","invoicemonth","rrbasis","cartons","poshareddate","piaapplicable","piareceived","piamodifiedtime","pbdapplicable","waybillrequired","appointmentrequired","podstatus","qtytobereceived","esttransittime","statuswc"]
df.drop(d,axis=1,inplace=True)
#df.info()
#df.head()

# %%
#df.drop(["poshareddate"],axis="columns",inplace=True)
#df.drop(["zone"],axis="columns",inplace=True)

# %%
#df.zone.value_counts()

# %%
df.head()
# Out:
#   warehouse  ordercreateddate  ordercreatedtime       orderno  customer_wh  \
# 0  BLRB012A             44018          0.589514  SO_001457910        10180
# 1  BLRB012A             44020          0.695162  SO_001464869        10490
# 2  BLRB013D             44019          0.699306  SO_001461049        10555
# 3  BLRB012A             44019          0.706250  SO_001461050        10555
# 4  BLRB012A             44019          0.708067  SO_001461051        10555
#
#            customer_whname   zone  shiptocity shiptostate  shiptopincode  ...  \
# 0  Buhler (India) Pvt. Ltd  South   Bangalore          KA       562107.0  ...
# 1             Parkash Sons  North  Chandigarh          CH       160017.0  ...
# 2            RANVIR STUDIO  North       Simla          HP       171001.0  ...
# 3            RANVIR STUDIO  North       Simla          HP       171001.0  ...
# 4            RANVIR STUDIO  North       Simla          HP       171001.0  ...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20048 entries, 0 to 20047
# Data columns (total 40 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   warehouse                 20048 non-null  object
#  1   ordercreateddate          20048 non-null  int64
#  2   ordercreatedtime          20048 non-null  float64
#  3   orderno                   20048 non-null  object
#  4   customer_wh               20048 non-null  int64
#  5   customer_whname           20048 non-null  object
#  6   zone                      73 non-null     object
#  7   shiptocity                20046 non-null  object
#  8   shiptostate               20046 non-null  object
#  9   shiptopincode             20047 non-null  float64
#  10  externaldoc_customerpono  20045 non-null  object
#  11  consignmentid             19940 non-null  object
#  12  orderqty                  20047 non-null  float64
# ...

# %%
df.drop(["zone","deliverydate"],axis="columns",inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20048 entries, 0 to 20047
# Data columns (total 38 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   warehouse                 20048 non-null  object
#  1   ordercreateddate          20048 non-null  int64
#  2   ordercreatedtime          20048 non-null  float64
#  3   orderno                   20048 non-null  object
#  4   customer_wh               20048 non-null  int64
#  5   customer_whname           20048 non-null  object
#  6   shiptocity                20046 non-null  object
#  7   shiptostate               20046 non-null  object
#  8   shiptopincode             20047 non-null  float64
#  9   externaldoc_customerpono  20045 non-null  object
#  10  consignmentid             19940 non-null  object
#  11  orderqty                  20047 non-null  float64
#  12  ordervalue                20047 non-null  float64
# ...

# %%
df.head()
# Out:
#   warehouse  ordercreateddate  ordercreatedtime       orderno  customer_wh  \
# 0  BLRB012A             44018          0.589514  SO_001457910        10180
# 1  BLRB012A             44020          0.695162  SO_001464869        10490
# 2  BLRB013D             44019          0.699306  SO_001461049        10555
# 3  BLRB012A             44019          0.706250  SO_001461050        10555
# 4  BLRB012A             44019          0.708067  SO_001461051        10555
#
#            customer_whname  shiptocity shiptostate  shiptopincode  \
# 0  Buhler (India) Pvt. Ltd   Bangalore          KA       562107.0
# 1             Parkash Sons  Chandigarh          CH       160017.0
# 2            RANVIR STUDIO       Simla          HP       171001.0
# 3            RANVIR STUDIO       Simla          HP       171001.0
# 4            RANVIR STUDIO       Simla          HP       171001.0
#
#   externaldoc_customerpono  ... invoicedate  invoicetime   rrdate  \
# ...

# %%
df.waybillno.value_counts(normalize=True)
# Out:
# NOT REQ    0.870015
# NOTREQD    0.129082
# Not Req    0.000903
# Name: waybillno, dtype: float64

# %%
df.to_csv("E:\\data\\hari.csv")
