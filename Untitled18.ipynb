# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv("E:\data\hari.csv")
# Out:
# E:\anakonda\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (34) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.head()
# Out:
#    Unnamed: 0 warehouse  ordercreateddate  ordercreatedtime       orderno  \
# 0           0  BLRB012A             44018          0.589514  SO_001457910
# 1           1  BLRB012A             44020          0.695162  SO_001464869
# 2           2  BLRB013D             44019          0.699306  SO_001461049
# 3           3  BLRB012A             44019          0.706250  SO_001461050
# 4           4  BLRB012A             44019          0.708067  SO_001461051
#
#    customer_wh          customer_whname  shiptocity shiptostate  \
# 0        10180  Buhler (India) Pvt. Ltd   Bangalore          KA
# 1        10490             Parkash Sons  Chandigarh          CH
# 2        10555            RANVIR STUDIO       Simla          HP
# 3        10555            RANVIR STUDIO       Simla          HP
# 4        10555            RANVIR STUDIO       Simla          HP
#
#    shiptopincode  ... invoicedate invoicetime   rrdate  dispatchdate_3pl_  \
# ...

# %%
df.drop(["Unnamed: 0"],axis="columns",inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20048 entries, 0 to 20047
# Data columns (total 38 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   warehouse                 20048 non-null  object
#  1   ordercreateddate          20048 non-null  int64
#  2   ordercreatedtime          20048 non-null  float64
#  3   orderno                   20048 non-null  object
#  4   customer_wh               20048 non-null  int64
#  5   customer_whname           20048 non-null  object
#  6   shiptocity                20046 non-null  object
#  7   shiptostate               20046 non-null  object
#  8   shiptopincode             20047 non-null  float64
#  9   externaldoc_customerpono  20045 non-null  object
#  10  consignmentid             19940 non-null  object
#  11  orderqty                  20047 non-null  float64
#  12  ordervalue                20047 non-null  float64
# ...

# %%
df.drop(["esugamno"],axis="columns",inplace=True)

# %%
df.drop(["lspname","iorderinvoiceqty"],axis="columns",inplace=True)

# %%
df.head()
# Out:
#   warehouse  ordercreateddate  ordercreatedtime       orderno  customer_wh  \
# 0  BLRB012A             44018          0.589514  SO_001457910        10180
# 1  BLRB012A             44020          0.695162  SO_001464869        10490
# 2  BLRB013D             44019          0.699306  SO_001461049        10555
# 3  BLRB012A             44019          0.706250  SO_001461050        10555
# 4  BLRB012A             44019          0.708067  SO_001461051        10555
#
#            customer_whname  shiptocity shiptostate  shiptopincode  \
# 0  Buhler (India) Pvt. Ltd   Bangalore          KA       562107.0
# 1             Parkash Sons  Chandigarh          CH       160017.0
# 2            RANVIR STUDIO       Simla          HP       171001.0
# 3            RANVIR STUDIO       Simla          HP       171001.0
# 4            RANVIR STUDIO       Simla          HP       171001.0
#
#   externaldoc_customerpono  ...     invoice_ptsno  invoicevalue  invoicedate  \
# ...

# %%
#df.warehouse.value_counts(normalize=True)
#sns.distplot(df.ordercreatedtime.value_counts())
df.drop(["orderno"],axis="columns",inplace=True)

# %%
#df.customer_wh.value_counts()
df.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-d3fcc8b4025e> in <module>
# ----> 1 dfdf.customer_wh.value_counts()
#
# NameError: name 'dfdf' is not defined
